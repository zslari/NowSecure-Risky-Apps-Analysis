# %%
import os
import json
import pandas as pd

# Path to the 'Group 1' directory
group1_path = 'Group 1'

# List to hold the data frames
dfs = []

# Iterate through each file in the 'Group 1' directory
for file in os.listdir(group1_path):
    # Check if the file has a .json extension
    if file.endswith('.json'):
        # Construct the full path to the file
        file_path = os.path.join(group1_path, file)
        
        # Open and read the JSON file
        with open(file_path, 'r') as json_file:
            data = json.load(json_file)
            
            # Convert the JSON data to a Pandas data frame and append to the list
            dfs.append(pd.json_normalize(data))

# At this point, dfs will contain all the data frames extracted from the JSON files

# %%
df.head()
# Out:
#                title    latestAnalysisRecorded  \
# 0  Spectator Judging  2020-12-21T09:58:30.110Z
# 1             LabFly  2021-05-18T11:00:09.185Z
# 2      Step Younger+  2020-04-15T11:32:32.135Z
#
#    assessment.analysis.task.dynamic  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#   assessment.analysis.task.static.result.yaap_data.js.tests  \
# 0    [method_annotations, method_args, method_calls]
# 1    [method_annotations, method_args, method_calls]
# 2                                                NaN
#
#   assessment.analysis.task.static.result.yaap_data.js.method_args.data  \
# 0  [{'line': -1, 'method': 'Landroid/webkit/WebVi...
# 1  [{'line': -1, 'method': 'Landroid/webkit/WebVi...
# 2                                                NaN
#
#   assessment.analysis.task.static.result.yaap_data.js.method_args.found  \
# 0                                               True
# ...

# %%
# Path to the specific JSON file in the 'Group 1' directory
file_path = 'Group 1/1004706f-12e7-428d-8533-81a17f7b138a.json'  

# Open and read the JSON file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)
    
    # Convert the JSON data to a Pandas data frame
    df = pd.json_normalize(data)

# At this point, df will contain the data frame extracted from the specific JSON file
df.head()
# Out:
#                                             title    latestAnalysisRecorded  \
# 0  Clone Evolution: Cyber War-Borderlands Fantasy  2020-09-01T20:42:01.987Z
# 1                2 Pics Quiz: Emoji Guessing Game  2020-05-06T14:38:56.195Z
#
#    assessment.analysis.task.dynamic.result.fs_issues  \
# 0  [{'mode': 384, 'path': '/sdcard/Android/data/c...
# 1  [{'mode': 384, 'path': '/sdcard/Android/data/c...
#
#   assessment.analysis.task.dynamic.result.http_info.unique_user_agents  \
# 0  [Dalvik/2.1.0 (Linux; U; Android 7.1.1; Nexus ...
# 1  [Dalvik/2.1.0 (Linux; U; Android 7.1.1; Nexus ...
#
#   assessment.analysis.task.dynamic.result.ipc_issues  \
# 0  [{'content_providers': [{'name': 'com.facebook...
# 1  [{'content_providers': [{'name': 'com.facebook...
#
#   assessment.analysis.task.dynamic.result.file_access.detailed_list  \
# 0  [{'p': 2881, 'ts': 1598991493017642, 'pid': 28...
# 1  [{'p': 26927, 'ts': 1588774709665500, 'pid': 2...
#
# ...

# %%
# Path to the specific JSON file in the 'Group 1' directory
file_path = 'Group 1/11984867-35b5-42df-b6bb-5d6061bb17a3.json'  

# Open and read the JSON file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)
    
    # Convert the JSON data to a Pandas data frame
    df = pd.json_normalize(data)

# %%
print(df)
# Out:
#            title latestAnalysisRecorded assessment
# 0  Gospel Living                   None       None

# %%
# Path to the specific JSON file in the 'Group 1' directory
file_path = 'Group 1/18643016-e4d5-43d7-9ccf-b4dfffea2e89.json'  

# Open and read the JSON file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)
    
    # Convert the JSON data to a Pandas data frame
    df = pd.json_normalize(data)
    
df.head()
# Out:
#                                            title    latestAnalysisRecorded  \
# 0  Four In A Row Online | Four In A Line Puzzles  2021-02-09T03:44:37.994Z
#
#    assessment.analysis.task.dynamic.result.fs_issues  \
# 0  [{'mode': 384, 'path': '/data/data/com.alignit...
#
#   assessment.analysis.task.dynamic.result.http_info.unique_user_agents  \
# 0  [Dalvik/2.1.0 (Linux; U; Android 7.1.1; Nexus ...
#
#   assessment.analysis.task.dynamic.result.ipc_issues  \
# 0                                                 []
#
#   assessment.analysis.task.dynamic.result.file_access.detailed_list  \
# 0  [{'p': 19550, 'ts': 1612840791182134, 'pid': 1...
#
#   assessment.analysis.task.dynamic.result.file_access.simplified_list  \
# 0  [/data/dalvik-cache/arm/data@app@com.alignit.f...
#
#   assessment.analysis.task.dynamic.result.run_summary.apk_info.md5  \
# 0                   DF17096A74E7305DF884B03D49718060
#
#   assessment.analysis.task.dynamic.result.run_summary.apk_info.sha1  \
# ...

# %%
# Path to the specific JSON file in the 'Group 1' directory
file_path = 'Group 1/329443cb-cc95-47d1-af00-c87342e6594e.json'  

# Open and read the JSON file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)
    
    # Convert the JSON data to a Pandas data frame
    df = pd.json_normalize(data)
    
df.head()
# Out:
#                                             title    latestAnalysisRecorded  \
# 0                               Cell Tracker Kids                      None
# 1                  Priceline - Hotel, Car, Flight  2021-09-09T06:04:49.976Z
# 2  WhatSmiley - Smileys, Stickers & WAStickerApps  2021-08-22T08:19:29.264Z
#
#    assessment assessment.analysis.task.dynamic.result.itunes.listing.kind  \
# 0         NaN                                                NaN
# 1         NaN                                           software
# 2         NaN                                                NaN
#
#    assessment.analysis.task.dynamic.result.itunes.listing.price  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
#
#   assessment.analysis.task.dynamic.result.itunes.listing.genres  \
# 0                                                NaN
# ...

# %%
# Path to the specific JSON file in the 'Group 1' directory
file_path = 'Group 1/58606500-d91a-461f-8888-3ad9f9329393.json'  

# Open and read the JSON file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)
    
    # Convert the JSON data to a Pandas data frame
    df = pd.json_normalize(data)
    
df.head()
# Out:
#                title    latestAnalysisRecorded  \
# 0  Spectator Judging  2020-12-21T09:58:30.110Z
# 1             LabFly  2021-05-18T11:00:09.185Z
# 2      Step Younger+  2020-04-15T11:32:32.135Z
#
#    assessment.analysis.task.dynamic  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#   assessment.analysis.task.static.result.yaap_data.js.tests  \
# 0    [method_annotations, method_args, method_calls]
# 1    [method_annotations, method_args, method_calls]
# 2                                                NaN
#
#   assessment.analysis.task.static.result.yaap_data.js.method_args.data  \
# 0  [{'line': -1, 'method': 'Landroid/webkit/WebVi...
# 1  [{'line': -1, 'method': 'Landroid/webkit/WebVi...
# 2                                                NaN
#
#   assessment.analysis.task.static.result.yaap_data.js.method_args.found  \
# 0                                               True
# ...

# %%
# Path to the specific JSON file in the 'Group 1' directory
file_path = 'Group 1/58606500-d91a-461f-8888-3ad9f9329393.json'  

# Open and read the JSON file
with open(file_path, 'r') as json_file:
    data = json.load(json_file)
    
    # Convert the JSON data to a Pandas data frame
    df = pd.json_normalize(data)
    
df.head()

# %%
import pandas as pd
import os
import json

# Directory containing JSON files
directory_path = './Group 1'  # Adjust path as needed

# Create an empty dataframe to store the stacked data
final_df = pd.DataFrame()

# Loop through each JSON file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".json"):
        with open(os.path.join(directory_path, filename), 'r') as f:
            data = json.load(f)
            
            # Convert JSON to dataframe and flatten the hierarchical structure
            temp_df = pd.json_normalize(data, max_level=2)  # Adjust max_level based on the depth of the JSON
            
            # Append the temp_df to final_df
            final_df = final_df.append(temp_df, ignore_index=True)

            
final_df.head()
# Save the final dataframe to a CSV (optional)
# final_df.to_csv('combined_data.csv', index=False)
# Out:
#                                                title  \
# 0                     Speak & Translate - Translator
# 1  theScore: Live Sports Scores, News, Stats & Vi...
# 2                                           FreeCell
# 3    Police Car Driving Simulator 3D: Car Games 2020
# 4                                        Hearthstone
#
#      latestAnalysisRecorded  \
# 0  2021-06-27T09:06:04.786Z
# 1  2021-08-30T00:11:32.388Z
# 2  2021-04-27T21:38:09.681Z
# 3                      None
# 4  2021-09-03T05:33:56.421Z
#
#                             assessment.analysis.task  \
# 0  {'dynamic': {'result': {'itunes': {'listing': ...
# 1  {'dynamic': {'result': {'fs_issues': [], 'http...
# 2  {'dynamic': {'result': {'fs_issues': [{'mode':...
# 3                                                NaN
# 4  {'dynamic': {'result': {'fs_issues': [], 'http...
#
#                          assessment.ref      assessment.publisherName  \
# ...

# %%
final_df.head(25)
# Out:
#                                                 title  \
# 0                      Speak & Translate - Translator
# 1   theScore: Live Sports Scores, News, Stats & Vi...
# 2                                            FreeCell
# 3     Police Car Driving Simulator 3D: Car Games 2020
# 4                                         Hearthstone
# 5    Multi-Play Video Poker™ - Free Video Poker Games
# 6                            EXiTS - Room Escape Game
# 7                                         Video Maker
# 8                                 Tracks4Africa Guide
# 9                                              Kardia
# 10                                      Gospel Living
# 11      Four In A Row Online | Four In A Line Puzzles
# 12     Clone Evolution: Cyber War-Borderlands Fantasy
# 13                   2 Pics Quiz: Emoji Guessing Game
# 14                                  Cell Tracker Kids
# 15                     Priceline - Hotel, Car, Flight
# ...

# %%
import pandas as pd
import os
import json

# Base directory containing group folders
base_directory = '.'  # Adjust path as needed, if the script isn't in the same location

# Create an empty dataframe to store the stacked data
final_df = pd.DataFrame()

# Loop through each directory named 'Group X'
for i in range(1, 8):  # Since there are 7 groups
    directory_path = os.path.join(base_directory, f'Group {i}')
    
    # Loop through each JSON file in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            with open(os.path.join(directory_path, filename), 'r') as f:
                data = json.load(f)
                
                # Convert JSON to dataframe and flatten the hierarchical structure
                temp_df = pd.json_normalize(data, max_level=2)  # Adjust max_level based on the depth of the JSON
                
                # Append the temp_df to final_df
                final_df = final_df.append(temp_df, ignore_index=True)

# %%
final_df.shape
# Out:
# (194, 13)

# %%
final_df.to_csv('combined_data.csv', index=False)
